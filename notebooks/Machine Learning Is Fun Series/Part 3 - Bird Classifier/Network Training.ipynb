# %%
# -*- coding: utf-8 -*-

"""
Based on the tflearn example located here:
https://github.com/tflearn/tflearn/blob/master/examples/images/convnet_cifar10.py
"""
from __future__ import division, print_function, absolute_import

# Import tflearn and some helpers
import tflearn
from tflearn.data_utils import shuffle
from tflearn.layers.core import input_data, dropout, fully_connected
from tflearn.layers.conv import conv_2d, max_pool_2d
from tflearn.layers.estimator import regression
from tflearn.data_preprocessing import ImagePreprocessing
from tflearn.data_augmentation import ImageAugmentation
import pickle

# Load the data set
data_file = '/aiuoa/datasets/birds_dataset.pkl'
with open(data_file, 'rb') as f:
    X, Y, X_test, Y_test = pickle.load(f)

# Shuffle the data
X, Y = shuffle(X, Y)

# Make sure the data is normalized
img_prep = ImagePreprocessing()
img_prep.add_featurewise_zero_center()
img_prep.add_featurewise_stdnorm()

# Create extra synthetic training data by flipping, rotating and blurring the
# images on our data set.
img_aug = ImageAugmentation()
img_aug.add_random_flip_leftright()
img_aug.add_random_rotation(max_angle=25.)
img_aug.add_random_blur(sigma_max=3.)

# Define our network architecture:

# Input is a 32x32 image with 3 color channels (red, green and blue)
network = input_data(shape=[None, 32, 32, 3],
                     data_preprocessing=img_prep,
                     data_augmentation=img_aug)

# Step 1: Convolution
network = conv_2d(network, 32, 3, activation='relu')

# Step 2: Max pooling
network = max_pool_2d(network, 2)

# Step 3: Convolution again
network = conv_2d(network, 64, 3, activation='relu')

# Step 4: Convolution yet again
network = conv_2d(network, 64, 3, activation='relu')

# Step 5: Max pooling again
network = max_pool_2d(network, 2)

# Step 6: Fully-connected 512 node neural network
network = fully_connected(network, 512, activation='relu')

# Step 7: Dropout - throw away some data randomly during training to prevent over-fitting
network = dropout(network, 0.5)

# Step 8: Fully-connected neural network with two outputs (0=isn't a bird, 1=is a bird) to make the final prediction
network = fully_connected(network, 2, activation='softmax')

# Tell tflearn how we want to train the network
network = regression(network, optimizer='adam',
                     loss='categorical_crossentropy',
                     learning_rate=0.001)

# Wrap the network in a model object
model = tflearn.DNN(network, tensorboard_verbose=0, checkpoint_path='/aiuoa/models/bird-classifier/model.tfl.ckpt')

# Train it! We'll do 100 training passes and monitor it as it goes.
model.fit(X, Y, n_epoch=100, shuffle=True, validation_set=(X_test, Y_test),
          show_metric=True, batch_size=96,
          snapshot_epoch=True,
          run_id='bird-classifier')

# Save model when training is complete to a file
model.save("/aiuoa/models/bird-classifier/model.tfl")
print("Network trained and saved as bird-classifier.tfl!")
# Out:
# Training Step: 3332  | total loss: 0.29852 | time: 129.352s
# | Adam | epoch: 006 | loss: 0.29852 - acc: 0.8764 -- iter: 35712/56780
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-1-e7ca6c449899> in <module>()
#      80           show_metric=True, batch_size=96,
#      81           snapshot_epoch=True,
# ---> 82           run_id='bird-classifier')
#      83
#      84 # Save model when training is complete to a file
#
# /usr/local/lib/python2.7/dist-packages/tflearn/models/dnn.pyc in fit(self, X_inputs, Y_targets, n_epoch, validation_set, show_metric, batch_size, shuffle, snapshot_epoch, snapshot_step, excl_trainops, validation_batch_size, run_id, callbacks)
#     214                          excl_trainops=excl_trainops,
#     215                          run_id=run_id,
# --> 216                          callbacks=callbacks)
#     217
#     218     def fit_batch(self, X_inputs, Y_targets):
#
# /usr/local/lib/python2.7/dist-packages/tflearn/helpers/trainer.pyc in fit(self, feed_dicts, n_epoch, val_feed_dicts, show_metric, snapshot_step, snapshot_epoch, shuffle_all, dprep_dict, daug_dict, excl_trainops, run_id, callbacks)
#     347                         # All optimizers batch end
#     348                         self.session.run(self.incr_global_step)
# --> 349                         caller.on_batch_end(self.training_state, snapshot)
#     350
#     351                     # Epoch end
#
# /usr/local/lib/python2.7/dist-packages/tflearn/callbacks.pyc in on_batch_end(self, training_state, snapshot)
#      74     def on_batch_end(self, training_state, snapshot=False):
#      75         for callback in self.callbacks:
# ---> 76             callback.on_batch_end(training_state, snapshot)
#      77
#      78     def on_epoch_end(self, training_state):
#
# /usr/local/lib/python2.7/dist-packages/tflearn/callbacks.pyc in on_batch_end(self, training_state, snapshot)
#     146             self.snapshot_termlogs(training_state)
#     147         else:
# --> 148             self.print_termlogs(training_state)
#     149
#     150     def on_sub_batch_begin(self, training_state):
#
# /usr/local/lib/python2.7/dist-packages/tflearn/callbacks.pyc in print_termlogs(self, training_state)
#     241
#     242         sys.stdout.write(termlogs)
# --> 243         sys.stdout.flush()
#     244
#     245     def snapshot_termlogs(self, training_state):
#
# /usr/local/lib/python2.7/dist-packages/ipykernel/iostream.pyc in flush(self)
#     347                 self.pub_thread.schedule(evt.set)
#     348                 # and give a timeout to avoid
# --> 349                 if not evt.wait(self.flush_timeout):
#     350                     # write directly to __stderr__ instead of warning because
#     351                     # if this is happening sys.stderr may be the problem.
#
# /usr/lib/python2.7/threading.pyc in wait(self, timeout)
#     612         with self.__cond:
#     613             if not self.__flag:
# --> 614                 self.__cond.wait(timeout)
#     615             return self.__flag
#     616
#
# /usr/lib/python2.7/threading.pyc in wait(self, timeout)
#     357                         break
#     358                     delay = min(delay * 2, remaining, .05)
# --> 359                     _sleep(delay)
#     360                 if not gotit:
#     361                     if __debug__:
#
# KeyboardInterrupt:
